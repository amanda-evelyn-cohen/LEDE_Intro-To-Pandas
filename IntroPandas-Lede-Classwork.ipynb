# %% [markdown]
# # Lede 2023 Classwork Assignment Pandas

# %%
# !pip install pandas

# %%
# this below changes my command of pandas to now be pd

# %%
import pandas as pd

# %%
#this allows me to read the countries files but if i press tab when writing cou.. it autocompletes

# %%
#also if i dont know what file type i want i can press shift tab tab tab and a whole documentation pops up on how to use

# %%
pd.read_csv('countries.csv')
# Out:
#                  country   continent  life_expectancy  population  \
# 0            Afghanistan        Asia           54.863    22856302
# 1                Albania      Europe           74.200     3071856
# 2                Algeria      Africa           68.963    30533827
# 3                 Angola      Africa           45.234    13926373
# 4    Antigua and Barbuda  N. America           73.544       77656
# ..                   ...         ...              ...         ...
# 183              Vietnam        Asia           73.777    78758010
# 184   West Bank and Gaza        Asia           70.929     3198560
# 185          Yemen, Rep.        Asia           60.404    17723186
# 186               Zambia      Africa           41.802    10201562
# 187             Zimbabwe      Africa           43.976    12509477
#
#               gdp
# 0     15153728226
# 1     12886435920
# 2    155661450046
# 3     34063908358
# 4       989182128
# ..            ...
# 183  124201381770
# ...

# %% [markdown]
# ##### holy shit this `pd.read_csv('countries.csv')` just found me this table which is called a dataframe; i want to save this into a variable so im gonna name this dataframe df BECAUSE dataframes are df and pandas are pd
#
# ###### NOTE DO NOT '(print)df' ---> if i want to look at a dataframe type 'df'

# %%
df = pd.read_csv('countries.csv')
df
# Out:
#                  country   continent  life_expectancy  population  \
# 0            Afghanistan        Asia           54.863    22856302
# 1                Albania      Europe           74.200     3071856
# 2                Algeria      Africa           68.963    30533827
# 3                 Angola      Africa           45.234    13926373
# 4    Antigua and Barbuda  N. America           73.544       77656
# ..                   ...         ...              ...         ...
# 183              Vietnam        Asia           73.777    78758010
# 184   West Bank and Gaza        Asia           70.929     3198560
# 185          Yemen, Rep.        Asia           60.404    17723186
# 186               Zambia      Africa           41.802    10201562
# 187             Zimbabwe      Africa           43.976    12509477
#
#               gdp
# 0     15153728226
# 1     12886435920
# 2    155661450046
# 3     34063908358
# 4       989182128
# ..            ...
# 183  124201381770
# ...

# %%
#to look at the first five of the data frame
df.head()
# Out:
#                country   continent  life_expectancy  population           gdp
# 0          Afghanistan        Asia           54.863    22856302   15153728226
# 1              Albania      Europe           74.200     3071856   12886435920
# 2              Algeria      Africa           68.963    30533827  155661450046
# 3               Angola      Africa           45.234    13926373   34063908358
# 4  Antigua and Barbuda  N. America           73.544       77656     989182128

# %%
#to look at the last five lines of the data frame
df.tail()
# Out:
#                 country continent  life_expectancy  population           gdp
# 183             Vietnam      Asia           73.777    78758010  124201381770
# 184  West Bank and Gaza      Asia           70.929     3198560   24264276160
# 185         Yemen, Rep.      Asia           60.404    17723186   39292303362
# 186              Zambia    Africa           41.802    10201562   10558616670
# 187            Zimbabwe    Africa           43.976    12509477    9319560365

# %%
#to sort data frames by the data you sort values; sorting index is those numbers on the left
df.sort_values(by='gdp')
# Out:
#                    country   continent  life_expectancy  population  \
# 142  Sao Tome and Principe      Africa        63.336000      141010
# 87                Kiribati     Oceania        64.642000       84010
# 169                  Tonga     Oceania        70.810000       97935
# 111  Micronesia, Fed. Sts.     Oceania        67.300000      107103
# 36                 Comoros      Africa        57.900000      562469
# ..                     ...         ...              ...         ...
# 75                   India        Asia        62.129000  1053898107
# 61                 Germany      Europe        78.141275    82349027
# 83                   Japan        Asia        81.350000   125720310
# 34                   China        Asia        72.124000  1269116737
# 178          United States  N. America        76.800000   282496310
#
#                 gdp
# 142       186133200
# 87        294119010
# 169       478510410
# 111       592279590
# 36        613091210
# ..              ...
# ...

# %%
#however pandas will always sort is ascending order but we want biggest to largest so we do ,as TAB to write ascending = False

df.sort_values(by='gdp', ascending= False)
# Out:
#                    country   continent  life_expectancy  population  \
# 178          United States  N. America        76.800000   282496310
# 34                   China        Asia        72.124000  1269116737
# 83                   Japan        Asia        81.350000   125720310
# 61                 Germany      Europe        78.141275    82349027
# 75                   India        Asia        62.129000  1053898107
# ..                     ...         ...              ...         ...
# 36                 Comoros      Africa        57.900000      562469
# 111  Micronesia, Fed. Sts.     Oceania        67.300000      107103
# 169                  Tonga     Oceania        70.810000       97935
# 87                Kiribati     Oceania        64.642000       84010
# 142  Sao Tome and Principe      Africa        63.336000      141010
#
#                 gdp
# 178  11231488292980
# 34    4323880722959
# 83    3590446333290
# 61    2447907176602
# 75    1736824080336
# ..              ...
# ...

# %%
#challenge: how to only get the top 5 use .head() --> that gives top five but if i want three i will do .head(3)

df.sort_values(by='gdp', ascending= False).head()
# Out:
#            country   continent  life_expectancy  population             gdp
# 178  United States  N. America        76.800000   282496310  11231488292980
# 34           China        Asia        72.124000  1269116737   4323880722959
# 83           Japan        Asia        81.350000   125720310   3590446333290
# 61         Germany      Europe        78.141275    82349027   2447907176602
# 75           India        Asia        62.129000  1053898107   1736824080336

# %%
#I need to know how to find each column one by one
#so let me start by looking at population column

df.population
# Out:
# 0      22856302
# 1       3071856
# 2      30533827
# 3      13926373
# 4         77656
#          ...
# 183    78758010
# 184     3198560
# 185    17723186
# 186    10201562
# 187    12509477
# Name: population, Length: 188, dtype: int64

# %%
#I want to find GDP per capita, which is GDP divided by population..what is that code?

df.gdp/df.population
# Out:
# 0        663.0
# 1       4195.0
# 2       5098.0
# 3       2446.0
# 4      12738.0
#         ...
# 183     1577.0
# 184     7586.0
# 185     2217.0
# 186     1035.0
# 187      745.0
# Length: 188, dtype: float64

# %%
df
# Out:
#                  country   continent  life_expectancy  population  \
# 0            Afghanistan        Asia           54.863    22856302
# 1                Albania      Europe           74.200     3071856
# 2                Algeria      Africa           68.963    30533827
# 3                 Angola      Africa           45.234    13926373
# 4    Antigua and Barbuda  N. America           73.544       77656
# ..                   ...         ...              ...         ...
# 183              Vietnam        Asia           73.777    78758010
# 184   West Bank and Gaza        Asia           70.929     3198560
# 185          Yemen, Rep.        Asia           60.404    17723186
# 186               Zambia      Africa           41.802    10201562
# 187             Zimbabwe      Africa           43.976    12509477
#
#               gdp
# 0     15153728226
# 1     12886435920
# 2    155661450046
# 3     34063908358
# 4       989182128
# ..            ...
# 183  124201381770
# ...

# %%
#adding a new column called gdp_per_capita
#NOTE: a period will aloow you to update a column that exists but NOT allow you to create a NEW column you must use square brackets then add the df.head()m so it knows to go into the header

df['gdp_per_capita'] = df.gdp / df.population
df.head()
# Out:
#                country   continent  life_expectancy  population           gdp  \
# 0          Afghanistan        Asia           54.863    22856302   15153728226
# 1              Albania      Europe           74.200     3071856   12886435920
# 2              Algeria      Africa           68.963    30533827  155661450046
# 3               Angola      Africa           45.234    13926373   34063908358
# 4  Antigua and Barbuda  N. America           73.544       77656     989182128
#
#    gdp_per_capita
# 0           663.0
# 1          4195.0
# 2          5098.0
# 3          2446.0
# 4         12738.0

# %%
#Note if i make a mistake delete my mistake then shift enter my way all the up to the top
#If i restart and run all it will run all my errors that i might have left too

# %%
#how do i find what continent is asia's data REMEMBER THE == df []
df[df.continent == "Asia"]
# Out:
#                   country continent  life_expectancy  population  \
# 0             Afghanistan      Asia           54.863    22856302
# 11                Bahrain      Asia           74.497      638193
# 12             Bangladesh      Asia           65.309   129592275
# 18                 Bhutan      Asia           60.307      571262
# 23                 Brunei      Asia           75.927      327036
# 27               Cambodia      Asia           62.030    12446949
# 34                  China      Asia           72.124  1269116737
# 72       Hong Kong, China      Asia           80.361     6783317
# 75                  India      Asia           62.129  1053898107
# 76              Indonesia      Asia           67.289   213395411
# 77                   Iran      Asia           69.611    65342319
# 78                   Iraq      Asia           70.845    23857458
# 80                 Israel      Asia           78.750     6014953
# ...

# %%
#THEN if i want to make this all above into a variable i will do

asian_countries = df[df.continent == "Asia"]

# %%
#If i only wanted to the top 5 would say 

asian_countries = df[df.continent == "Asia"]
asian_countries.head()
# Out:
#         country continent  life_expectancy  population           gdp  \
# 0   Afghanistan      Asia           54.863    22856302   15153728226
# 11      Bahrain      Asia           74.497      638193   14049818895
# 12   Bangladesh      Asia           65.309   129592275  139311695625
# 18       Bhutan      Asia           60.307      571262    1669227564
# 23       Brunei      Asia           75.927      327036   15704268720
#
#     gdp_per_capita
# 0            663.0
# 11         22015.0
# 12          1075.0
# 18          2922.0
# 23         48020.0

# %%
#list out all the countries with a life expectancy greather than 45

df[df.life_expectancy > 45]
# Out:
#                  country   continent  life_expectancy  population  \
# 0            Afghanistan        Asia           54.863    22856302
# 1                Albania      Europe           74.200     3071856
# 2                Algeria      Africa           68.963    30533827
# 3                 Angola      Africa           45.234    13926373
# 4    Antigua and Barbuda  N. America           73.544       77656
# ..                   ...         ...              ...         ...
# 181              Vanuatu     Oceania           67.438      185074
# 182            Venezuela  S. America           72.432    24348304
# 183              Vietnam        Asia           73.777    78758010
# 184   West Bank and Gaza        Asia           70.929     3198560
# 185          Yemen, Rep.        Asia           60.404    17723186
#
#               gdp  gdp_per_capita
# 0     15153728226           663.0
# 1     12886435920          4195.0
# 2    155661450046          5098.0
# ...

# %%
#average life expectancy using median 

df.life_expectancy.median()
# Out:
# 70.04150000000001

# %%
#average life expectancy using mean

df.life_expectancy.mean()
# Out:
# 66.50153603526596

# %%
#average life expectancy by continent

df.groupby(by='continent').life_expectancy.median()
# Out:
# continent
# Africa        52.1025
# Asia          70.4275
# Europe        75.5800
# N. America    70.5765
# Oceania       67.4955
# S. America    70.7660
# Name: life_expectancy, dtype: float64

# %%
#lets round it


df.groupby(by='continent').life_expectancy.median().round()
# Out:
# continent
# Africa        52.0
# Asia          70.0
# Europe        76.0
# N. America    71.0
# Oceania       67.0
# S. America    71.0
# Name: life_expectancy, dtype: float64

# %%
#sort by life expenctancy values by .sort_values() ; 

df.groupby(by='continent').life_expectancy.median().sort_values()
# Out:
# continent
# Africa        52.1025
# Oceania       67.4955
# Asia          70.4275
# N. America    70.5765
# S. America    70.7660
# Europe        75.5800
# Name: life_expectancy, dtype: float64

# %%
#however it sorts ascending so lets do biggest to largest akaka (ascending=False)

df.groupby(by='continent').life_expectancy.median().sort_values(ascending=False)
# Out:
# continent
# Europe        75.5800
# S. America    70.7660
# N. America    70.5765
# Asia          70.4275
# Oceania       67.4955
# Africa        52.1025
# Name: life_expectancy, dtype: float64

# %%
#this counts how many columnns have that continent
df.continent.value_counts()
# Out:
# continent
# Africa        54
# Asia          48
# Europe        42
# N. America    22
# S. America    12
# Oceania       10
# Name: count, dtype: int64

# %%
#if i want to save just the above to a csv first save this as a variable 
#this will look like a float with weird decimals, we want this to be an integer wite .astype(int) at the end 
continent_le = df.groupby(by='continent').life_expectancy.median().sort_values(ascending = False).astype(int)

# %%
#convert a series into a dataframe
continent_le.reset_index()
# Out:
#     continent  life_expectancy
# 0      Europe               75
# 1  S. America               70
# 2  N. America               70
# 3        Asia               70
# 4     Oceania               67
# 5      Africa               52

# %%
#then save it as a csv write .to_csv
#index False prevents those stupid left numbers from appearing
continent_le.to_csv('continent_lifeexpect.csv')
df.to_csv("cont_total.csv", index=False)

# %%
#let's see what else is in this folder so i can merge other datasets
# !ls
# Out:
# IntroPandas-Lede-Classwork.ipynb continent_lifeexpect.csv
# cont_total.csv                   countries.csv
# continent_facts.csv              merged_datasets.csv

# %%
#okay so i want to create a variable to read the continent facts csv. to read a csv file use the below code and create a variavle called continents
#remember .head() shows the first five so i can change 
continents = pd.read_csv("continent_facts.csv")
continents.head()
# Out:
#        continent  sqmi_mil
# 0           Asia    17.210
# 1         Europe     3.931
# 2         Africa    11.730
# 3  North America     9.540
# 4  South America     6.888

# %%
df.head(2)
# Out:
#        country continent  life_expectancy  population          gdp  \
# 0  Afghanistan      Asia           54.863    22856302  15153728226
# 1      Albania    Europe           74.200     3071856  12886435920
#
#    gdp_per_capita
# 0           663.0
# 1          4195.0

# %%
#counts the rows and columns BUT looks like its bc one is N AMerican one is North America

df.shape
# Out:
# (188, 6)

# %%
#to merge two dataframes with the same column aka continents 
#note that left on and right on are the columns we are matching

merged = df.merge(continents, 
         left_on='continent', 
         right_on='continent')
merged.head()
# Out:
#        country continent  life_expectancy  population           gdp  \
# 0  Afghanistan      Asia           54.863    22856302   15153728226
# 1      Bahrain      Asia           74.497      638193   14049818895
# 2   Bangladesh      Asia           65.309   129592275  139311695625
# 3       Bhutan      Asia           60.307      571262    1669227564
# 4       Brunei      Asia           75.927      327036   15704268720
#
#    gdp_per_capita  sqmi_mil
# 0           663.0     17.21
# 1         22015.0     17.21
# 2          1075.0     17.21
# 3          2922.0     17.21
# 4         48020.0     17.21

# %%
df
# Out:
#                  country   continent  life_expectancy  population  \
# 0            Afghanistan        Asia           54.863    22856302
# 1                Albania      Europe           74.200     3071856
# 2                Algeria      Africa           68.963    30533827
# 3                 Angola      Africa           45.234    13926373
# 4    Antigua and Barbuda  N. America           73.544       77656
# ..                   ...         ...              ...         ...
# 183              Vietnam        Asia           73.777    78758010
# 184   West Bank and Gaza        Asia           70.929     3198560
# 185          Yemen, Rep.        Asia           60.404    17723186
# 186               Zambia      Africa           41.802    10201562
# 187             Zimbabwe      Africa           43.976    12509477
#
#               gdp  gdp_per_capita
# 0     15153728226           663.0
# 1     12886435920          4195.0
# 2    155661450046          5098.0
# ...

# %%
#if we want to keep rows from df that dont have an exact name match in the two datasets we are merging, we use:
#how = left

merged = df.merge(continents, 
    left_on='continent', 
    right_on='continent',
    how = 'left')  
merged.head()
# Out:
#                country   continent  life_expectancy  population           gdp  \
# 0          Afghanistan        Asia           54.863    22856302   15153728226
# 1              Albania      Europe           74.200     3071856   12886435920
# 2              Algeria      Africa           68.963    30533827  155661450046
# 3               Angola      Africa           45.234    13926373   34063908358
# 4  Antigua and Barbuda  N. America           73.544       77656     989182128
#
#    gdp_per_capita  sqmi_mil
# 0           663.0    17.210
# 1          4195.0     3.931
# 2          5098.0    11.730
# 3          2446.0    11.730
# 4         12738.0       NaN

# %%
#what is even better is to replace the mismatched column names
#This only works on exact matches on a value

df.continent = df.continent.replace({
    'N. America': 'North America',
    'S. America': 'South America'
})

# %%
#so the code above works we have to repeat the code on line 152

#if we want to keep rows from df that dont have an exact name match in the two datasets we are merging, we use:
#how = left

merged = df.merge(continents, 
    left_on='continent', 
    right_on='continent',
    how = 'left')  
merged.head()
# Out:
#                country      continent  life_expectancy  population  \
# 0          Afghanistan           Asia           54.863    22856302
# 1              Albania         Europe           74.200     3071856
# 2              Algeria         Africa           68.963    30533827
# 3               Angola         Africa           45.234    13926373
# 4  Antigua and Barbuda  North America           73.544       77656
#
#             gdp  gdp_per_capita  sqmi_mil
# 0   15153728226           663.0    17.210
# 1   12886435920          4195.0     3.931
# 2  155661450046          5098.0    11.730
# 3   34063908358          2446.0    11.730
# 4     989182128         12738.0     9.540

# %%
#checks if the merge actually worked

df.head(10)
# Out:
#                country      continent  life_expectancy  population  \
# 0          Afghanistan           Asia           54.863    22856302
# 1              Albania         Europe           74.200     3071856
# 2              Algeria         Africa           68.963    30533827
# 3               Angola         Africa           45.234    13926373
# 4  Antigua and Barbuda  North America           73.544       77656
# 5            Argentina  South America           73.822    36930709
# 6              Armenia         Europe           71.494     3076098
# 7            Australia        Oceania           79.930    19164351
# 8              Austria         Europe           78.330     8004712
# 9           Azerbaijan         Europe           66.851     8110723
#
#             gdp  gdp_per_capita
# 0   15153728226           663.0
# 1   12886435920          4195.0
# 2  155661450046          5098.0
# 3   34063908358          2446.0
# 4     989182128         12738.0
# ...

# %%
merged.head()
# Out:
#                country      continent  life_expectancy  population  \
# 0          Afghanistan           Asia           54.863    22856302
# 1              Albania         Europe           74.200     3071856
# 2              Algeria         Africa           68.963    30533827
# 3               Angola         Africa           45.234    13926373
# 4  Antigua and Barbuda  North America           73.544       77656
#
#             gdp  gdp_per_capita  sqmi_mil
# 0   15153728226           663.0    17.210
# 1   12886435920          4195.0     3.931
# 2  155661450046          5098.0    11.730
# 3   34063908358          2446.0    11.730
# 4     989182128         12738.0     9.540

# %%
#this checks that all the continents are now changed names

continents = pd.read_csv("continent_facts.csv")
continents.head()
# Out:
#        continent  sqmi_mil
# 0           Asia    17.210
# 1         Europe     3.931
# 2         Africa    11.730
# 3  North America     9.540
# 4  South America     6.888

# %%
#count

df
# Out:
#                  country      continent  life_expectancy  population  \
# 0            Afghanistan           Asia           54.863    22856302
# 1                Albania         Europe           74.200     3071856
# 2                Algeria         Africa           68.963    30533827
# 3                 Angola         Africa           45.234    13926373
# 4    Antigua and Barbuda  North America           73.544       77656
# ..                   ...            ...              ...         ...
# 183              Vietnam           Asia           73.777    78758010
# 184   West Bank and Gaza           Asia           70.929     3198560
# 185          Yemen, Rep.           Asia           60.404    17723186
# 186               Zambia         Africa           41.802    10201562
# 187             Zimbabwe         Africa           43.976    12509477
#
#               gdp  gdp_per_capita
# 0     15153728226           663.0
# 1     12886435920          4195.0
# ...
